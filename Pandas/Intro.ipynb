# %% [markdown]
# # It's a Package provide's a fast, flexible and expressive data structure designed to work with "relational" & "Labeled" data.

# %% [markdown]
# # Use to analyzing, cleaning, exploring and manipulating data.
#
# # 2008

# %% [markdown]
# # easy to handing of missing data

# %% [markdown]
# # Size mutability :- Insert and deletion from DataFramw and higher dimentional Obj..

# %% [markdown]
# # Use Series.
#
# # Use as Flexible and Reshaping and pivoting of data sets.
#
# # Merge and Join the Data.

# %% [markdown]
# # Series:- 1 col 'n' rows data [Scaler].
#
# # Dataframe :- 'n' col, 'n' rows..

# %%
# Creation of DataFrame in Pandas.

print("Hello NS LONI")
# Out:
# Hello NS LONI

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\nagar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
#Using Python

data = {
    
    "name": ["Ns-1", "Ns-2", "NS-3"],
    "age": [21,20,20.9],
    "num":[1,2,3]  
       }

print(data)
# Out:
# {'name': ['Ns-1', 'Ns-2', 'NS-3'], 'age': [21, 20, 20.9], 'num': [1, 2, 3]}

# %%
# Using  a Pandas

df = pd.DataFrame(data)

print(df)
# Out:
#    name   age  num
# 0  Ns-1  21.0    1
# 1  Ns-2  20.0    2
# 2  NS-3  20.9    3

# %%
data = pd.read_csv('survey_results_public.csv')

print(data)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
## shape / size

print(data.shape)
# Out:
# (25, 85)

# %%
## Size

print(data.size)
# Out:
# 2125

# %%
##  Install openpyxl for excle

# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\nagar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\nagar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
## Read excle sheet

data = pd.read_excel('airline.xls')

print(data)
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
## Exploring a Data In Pandas

# Top 5 row

print(data.head(10))
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711
# 6  1954  3.025  0.335  0.4025  1.964  0.776
# 7  1955  3.562  0.350  0.3961  2.116  0.827
# 8  1956  3.979  0.361  0.3822  2.435  0.800
# 9  1957  4.420  0.379  0.3045  2.707  0.921

# %%
## Bottum

print(data.tail(10))
# Out:
#     YEAR       Y      W       R      L      K
# 22  1970  16.002  0.831  0.1883  5.495  7.627
# 23  1971  15.876  0.906  0.2023  5.334  8.673
# 24  1972  16.662  1.000  0.2506  5.345  8.331
# 25  1973  17.014  1.056  0.2668  5.662  8.557
# 26  1974  19.305  1.131  0.2664  5.729  9.508
# 27  1975  18.721  1.247  0.2301  5.722  9.062
# 28  1976  19.250  1.375  0.3452  5.762  8.262
# 29  1977  20.647  1.544  0.4508  5.877  7.474
# 30  1978  22.726  1.703  0.5877  6.108  7.104
# 31  1979  23.619  1.779  0.5346  6.852  6.874

# %%
## Default Value == 5

print(data.head())
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574

# %%
## Inforamtiom

print(data.info)
# Out:
# <bound method DataFrame.info of     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
## Describe the data min, max, %, count, 25%, 50%, 75%, std, mean etc

data.describe()
# Out:
#               YEAR          Y          W          R          L          K
# count    32.000000  32.000000  32.000000  32.000000  32.000000  32.000000
# mean   1963.500000  10.050187   0.691344   0.354931   3.793375   3.736281
# std       9.380832   7.255404   0.441908   0.115031   1.708000   3.304078
# min    1948.000000   1.214000   0.243000   0.145400   1.384000   0.559000
# 25%    1955.750000   3.874750   0.358250   0.266700   2.355250   0.820250
# 50%    1963.500000   7.349500   0.522000   0.350550   3.337500   2.019000
# 75%    1971.250000  16.400250   0.929500   0.406375   5.513500   7.196500
# max    1979.000000  23.619000   1.779000   0.587900   6.852000   9.508000

# %%
# Find No.of null Value's

## Not-Null value   

print(data.isnull())  # True---> null
# Out:
#      YEAR      Y      W      R      L      K
# 0   False  False  False  False  False  False
# 1   False  False  False  False  False  False
# 2   False  False  False  False  False  False
# 3   False  False  False  False  False  False
# 4   False  False  False  False  False  False
# 5   False  False  False  False  False  False
# 6   False  False  False  False  False  False
# 7   False  False  False  False  False  False
# 8   False  False  False  False  False  False
# 9   False  False  False  False  False  False
# 10  False  False  False  False  False  False
# 11  False  False  False  False  False  False
# 12  False  False  False  False  False  False
# 13  False  False  False  False  False  False
# 14  False  False  False  False  False  False
# 15  False  False  False  False  False  False
# 16  False  False  False  False  False  False
# 17  False  False  False  False  False  False
# 18  False  False  False  False  False  False
# 19  False  False  False  False  False  False
# ...

# %%
## sum of null value 

print(data.isnull().sum())
# Out:
# YEAR    0
# Y       0
# W       0
# R       0
# L       0
# K       0
# dtype: int64

# %%
##  Dealing with Duplicate value's in Pandas

data = pd.read_csv('survey_results_public.csv')

print(data)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
## Duplication

print(data.duplicated())  # no duplication value
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# dtype: bool

# %%
## drop_duplicates 

print(data.drop_duplicates())
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
##  Working with Missing Data in Pandas

# null-->,     
# NaN--> Int's, 
# None--> 


# Drop null value

print(data.dropna())
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 19          20  I am not primarily a developer, but I write co...       No
#
#    OpenSourcer                                         OpenSource  \
# 19       Never  OSS is, on average, of HIGHER quality than pro...
#
#             Employment    Country Student  \
# 19  Employed full-time  Lithuania      No
#
#                                           EdLevel  \
# 19  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                        UndergradMajor  ...  \
# 19  Information systems, information technology, o...  ...
#
#                                         WelcomeChange  \
# 19  Not applicable - I did not use Stack Overflow ...
#
#                                  SONewContent   Age  Gender  Trans  \
# 19  Tech articles written by other developers  38.0     Man     No
#
#                   Sexuality                     Ethnicity Dependents  \
# ...

# %%
## replace nan---> "nsloni-nsloni"

import numpy as ns

print(data.replace("Yes", "NSLONI"))
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code   NSLONI
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...   NSLONI
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession   NSLONI
# 5            6  I am not primarily a developer, but I write co...   NSLONI
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby   NSLONI
# 8            9                     I am a developer by profession   NSLONI
# 9           10                     I am a developer by profession   NSLONI
# 10          11                        I code primarily as a hobby   NSLONI
# ...

# %%
## find the   mean

print(data["Respondent"].mean())
# Out:
# 13.0

# %%
##   Backword file 

# Below name replace to above none name value

print(data.fillna(method="bfill"))
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
##  Forword file 

# Above name replace to Below none name value

print(data.fillna(method="ffill"))
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
## fill any things

print(data.fillna("loni"))
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
# ...

# %%
# Column Transformation 

## Read excle sheet

data = pd.read_excel('airline.xls')

print(data)
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
'''
##  YEAR       Y      W       R      L      K

import numpy as np
df.loc[np.isclose(df['y'], 7.823), "NS-LONI"] = "loni"


print(data)

'''
# Out:
# '\n##  YEAR       Y      W       R      L      K\n\nimport numpy as np\ndf.loc[np.isclose(df[\'y\'], 7.823), "NS-LONI"] = "loni"\n\n\nprint(data)\n\n'

# %%
# data["Total"] = data['Y'] + " " + data["R"]

# print(data)

# %%
# Sum error bcz of excel file not correct for converting read and understand
'''
data['Bonus'] = (data['Salary'] / 100) * 200

print(data)
'''
# Out:
# "\ndata['Bonus'] = (data['Salary'] / 100) * 200\n\nprint(data)\n"

# %%
print("NS LONI")
# Out:
# NS LONI
