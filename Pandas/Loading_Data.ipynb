# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\nagar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nagar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nagar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nagar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nagar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\nagar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\nagar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

print(df)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# ..         ...                                                ...      ...
# 20          21                        I code primarily as a hobby      Yes
# 21          22                     I am a developer by profession      Yes
# 22          23                     I am a developer by profession      Yes
# 23          24                     I am a developer by profession      Yes
# 24          25                     I am a developer by profession       No
#
#                    OpenSourcer  \
# 0                        Never
# 1      Less than once per year
# 2                        Never
# 3                        Never
# 4   Once a month or more often
# ..                         ...
# 20  Once a month or more often
# 21     Less than once per year
# 22     Less than once per year
# 23                       Never
# 24                       Never
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# 1   The quality of OSS and closed source software ...
# 2   The quality of OSS and closed source software ...
# 3   The quality of OSS and closed source software ...
# 4   OSS is, on average, of HIGHER quality than pro...
# ..                                                ...
# 20  OSS is, on average, of HIGHER quality than pro...
# 21  OSS is, on average, of HIGHER quality than pro...
# 22  The quality of OSS and closed source software ...
# 23  OSS is, on average, of HIGHER quality than pro...
# 24  OSS is, on average, of HIGHER quality than pro...
#
#                                 Employment                 Country  \
# 0   Not employed, and not looking for work          United Kingdom
# 1       Not employed, but looking for work  Bosnia and Herzegovina
# 2                       Employed full-time                Thailand
# 3                       Employed full-time           United States
# 4                       Employed full-time                 Ukraine
# ..                                     ...                     ...
# 20                                     NaN                  Canada
# 21                      Employed full-time           United States
# 22                      Employed full-time           United States
# 23                      Employed full-time                  Israel
# 24                      Employed full-time            South Africa
#
#            Student                                            EdLevel  \
# 0               No                          Primary/elementary school
# 1   Yes, full-time  Secondary school (e.g. American high school, G...
# 2               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# ..             ...                                                ...
# 20             NaN                                                NaN
# 21              No  Some college/university study without earning ...
# 22              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23              No                          Primary/elementary school
# 24              No                                   Associate degree
#
#                                        UndergradMajor  ...  \
# 0                                                 NaN  ...
# 1                                                 NaN  ...
# 2                       Web development or web design  ...
# 3   Computer science, computer engineering, or sof...  ...
# 4   Computer science, computer engineering, or sof...  ...
# ..                                                ...  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22  Information systems, information technology, o...  ...
# 23                                                NaN  ...
# 24  Computer science, computer engineering, or sof...  ...
#
#                                         WelcomeChange  \
# 0             Just as welcome now as I felt last year
# 1             Just as welcome now as I felt last year
# 2             Just as welcome now as I felt last year
# 3             Just as welcome now as I felt last year
# 4             Just as welcome now as I felt last year
# ..                                                ...
# 20  Not applicable - I did not use Stack Overflow ...
# 21            Just as welcome now as I felt last year
# 22            Just as welcome now as I felt last year
# 23            Just as welcome now as I felt last year
# 24            Just as welcome now as I felt last year
#
#                                          SONewContent   Age  Gender  Trans  \
# 0   Tech articles written by other developers;Indu...  14.0     Man     No
# 1   Tech articles written by other developers;Indu...  19.0     Man     No
# 2   Tech meetups or events in your area;Courses on...  28.0     Man     No
# 3   Tech articles written by other developers;Indu...  22.0     Man     No
# 4   Tech meetups or events in your area;Courses on...  30.0     Man     No
# ..                                                ...   ...     ...    ...
# 20                                                NaN   NaN     Man     No
# 21  Tech articles written by other developers;Indu...  47.0     Man     No
# 22  Tech articles written by other developers;Tech...  22.0     Man     No
# 23  Tech articles written by other developers;Indu...  23.0     Man     No
# 24                Tech meetups or events in your area  22.0     Man     No
#
#                   Sexuality                                 Ethnicity  \
# 0   Straight / Heterosexual                                       NaN
# 1   Straight / Heterosexual                                       NaN
# 2   Straight / Heterosexual                                       NaN
# 3   Straight / Heterosexual              White or of European descent
# 4   Straight / Heterosexual  White or of European descent;Multiracial
# ..                      ...                                       ...
# 20                      NaN                                       NaN
# 21  Straight / Heterosexual              White or of European descent
# 22  Straight / Heterosexual               Black or of African descent
# 23  Straight / Heterosexual                            Middle Eastern
# 24  Straight / Heterosexual              White or of European descent
#
#    Dependents           SurveyLength                  SurveyEase
# 0          No  Appropriate in length  Neither easy nor difficult
# 1          No  Appropriate in length  Neither easy nor difficult
# 2         Yes  Appropriate in length  Neither easy nor difficult
# 3          No  Appropriate in length                        Easy
# 4          No  Appropriate in length                        Easy
# ..        ...                    ...                         ...
# 20         No  Appropriate in length                        Easy
# 21        Yes  Appropriate in length                        Easy
# 22         No  Appropriate in length                        Easy
# 23         No  Appropriate in length                        Easy
# 24         No              Too short  Neither easy nor difficult
#
# [25 rows x 85 columns]

# %%
# shape --> no.of --> row/col

df.shape
# Out:
# (25, 85)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# ..         ...                                                ...      ...
# 20          21                        I code primarily as a hobby      Yes
# 21          22                     I am a developer by profession      Yes
# 22          23                     I am a developer by profession      Yes
# 23          24                     I am a developer by profession      Yes
# 24          25                     I am a developer by profession       No
#
#                    OpenSourcer  \
# 0                        Never
# 1      Less than once per year
# 2                        Never
# 3                        Never
# 4   Once a month or more often
# ..                         ...
# 20  Once a month or more often
# 21     Less than once per year
# 22     Less than once per year
# 23                       Never
# 24                       Never
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# 1   The quality of OSS and closed source software ...
# 2   The quality of OSS and closed source software ...
# 3   The quality of OSS and closed source software ...
# 4   OSS is, on average, of HIGHER quality than pro...
# ..                                                ...
# 20  OSS is, on average, of HIGHER quality than pro...
# 21  OSS is, on average, of HIGHER quality than pro...
# 22  The quality of OSS and closed source software ...
# 23  OSS is, on average, of HIGHER quality than pro...
# 24  OSS is, on average, of HIGHER quality than pro...
#
#                                 Employment                 Country  \
# 0   Not employed, and not looking for work          United Kingdom
# 1       Not employed, but looking for work  Bosnia and Herzegovina
# 2                       Employed full-time                Thailand
# 3                       Employed full-time           United States
# 4                       Employed full-time                 Ukraine
# ..                                     ...                     ...
# 20                                     NaN                  Canada
# 21                      Employed full-time           United States
# 22                      Employed full-time           United States
# 23                      Employed full-time                  Israel
# 24                      Employed full-time            South Africa
#
#            Student                                            EdLevel  \
# 0               No                          Primary/elementary school
# 1   Yes, full-time  Secondary school (e.g. American high school, G...
# 2               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# ..             ...                                                ...
# 20             NaN                                                NaN
# 21              No  Some college/university study without earning ...
# 22              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23              No                          Primary/elementary school
# 24              No                                   Associate degree
#
#                                        UndergradMajor  ...  \
# 0                                                 NaN  ...
# 1                                                 NaN  ...
# 2                       Web development or web design  ...
# 3   Computer science, computer engineering, or sof...  ...
# 4   Computer science, computer engineering, or sof...  ...
# ..                                                ...  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22  Information systems, information technology, o...  ...
# 23                                                NaN  ...
# 24  Computer science, computer engineering, or sof...  ...
#
#                                         WelcomeChange  \
# 0             Just as welcome now as I felt last year
# 1             Just as welcome now as I felt last year
# 2             Just as welcome now as I felt last year
# 3             Just as welcome now as I felt last year
# 4             Just as welcome now as I felt last year
# ..                                                ...
# 20  Not applicable - I did not use Stack Overflow ...
# 21            Just as welcome now as I felt last year
# 22            Just as welcome now as I felt last year
# 23            Just as welcome now as I felt last year
# 24            Just as welcome now as I felt last year
#
#                                          SONewContent   Age  Gender  Trans  \
# 0   Tech articles written by other developers;Indu...  14.0     Man     No
# 1   Tech articles written by other developers;Indu...  19.0     Man     No
# 2   Tech meetups or events in your area;Courses on...  28.0     Man     No
# 3   Tech articles written by other developers;Indu...  22.0     Man     No
# 4   Tech meetups or events in your area;Courses on...  30.0     Man     No
# ..                                                ...   ...     ...    ...
# 20                                                NaN   NaN     Man     No
# 21  Tech articles written by other developers;Indu...  47.0     Man     No
# 22  Tech articles written by other developers;Tech...  22.0     Man     No
# 23  Tech articles written by other developers;Indu...  23.0     Man     No
# 24                Tech meetups or events in your area  22.0     Man     No
#
#                   Sexuality                                 Ethnicity  \
# 0   Straight / Heterosexual                                       NaN
# 1   Straight / Heterosexual                                       NaN
# 2   Straight / Heterosexual                                       NaN
# 3   Straight / Heterosexual              White or of European descent
# 4   Straight / Heterosexual  White or of European descent;Multiracial
# ..                      ...                                       ...
# 20                      NaN                                       NaN
# 21  Straight / Heterosexual              White or of European descent
# 22  Straight / Heterosexual               Black or of African descent
# 23  Straight / Heterosexual                            Middle Eastern
# 24  Straight / Heterosexual              White or of European descent
#
#    Dependents           SurveyLength                  SurveyEase
# 0          No  Appropriate in length  Neither easy nor difficult
# 1          No  Appropriate in length  Neither easy nor difficult
# 2         Yes  Appropriate in length  Neither easy nor difficult
# 3          No  Appropriate in length                        Easy
# 4          No  Appropriate in length                        Easy
# ..        ...                    ...                         ...
# 20         No  Appropriate in length                        Easy
# 21        Yes  Appropriate in length                        Easy
# 22         No  Appropriate in length                        Easy
# 23         No  Appropriate in length                        Easy
# 24         No              Too short  Neither easy nor difficult
#
# [25 rows x 85 columns]>

# %%
pd.set_option('display.max_columns', 20)



pd.set_option('display.max_rows', 10)

# %%
shema_pd = pd.read_csv('survey_results_public.csv')

shema_pd
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# ..         ...                                                ...      ...
# 20          21                        I code primarily as a hobby      Yes
# 21          22                     I am a developer by profession      Yes
# 22          23                     I am a developer by profession      Yes
# 23          24                     I am a developer by profession      Yes
# 24          25                     I am a developer by profession       No
#
#                    OpenSourcer  \
# 0                        Never
# 1      Less than once per year
# 2                        Never
# 3                        Never
# 4   Once a month or more often
# ..                         ...
# 20  Once a month or more often
# 21     Less than once per year
# 22     Less than once per year
# 23                       Never
# 24                       Never
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# 1   The quality of OSS and closed source software ...
# 2   The quality of OSS and closed source software ...
# 3   The quality of OSS and closed source software ...
# 4   OSS is, on average, of HIGHER quality than pro...
# ..                                                ...
# 20  OSS is, on average, of HIGHER quality than pro...
# 21  OSS is, on average, of HIGHER quality than pro...
# 22  The quality of OSS and closed source software ...
# 23  OSS is, on average, of HIGHER quality than pro...
# 24  OSS is, on average, of HIGHER quality than pro...
#
#                                 Employment                 Country  \
# 0   Not employed, and not looking for work          United Kingdom
# 1       Not employed, but looking for work  Bosnia and Herzegovina
# 2                       Employed full-time                Thailand
# 3                       Employed full-time           United States
# 4                       Employed full-time                 Ukraine
# ..                                     ...                     ...
# 20                                     NaN                  Canada
# 21                      Employed full-time           United States
# 22                      Employed full-time           United States
# 23                      Employed full-time                  Israel
# 24                      Employed full-time            South Africa
#
#            Student                                            EdLevel  \
# 0               No                          Primary/elementary school
# 1   Yes, full-time  Secondary school (e.g. American high school, G...
# 2               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# ..             ...                                                ...
# 20             NaN                                                NaN
# 21              No  Some college/university study without earning ...
# 22              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23              No                          Primary/elementary school
# 24              No                                   Associate degree
#
#                                        UndergradMajor  ...  \
# 0                                                 NaN  ...
# 1                                                 NaN  ...
# 2                       Web development or web design  ...
# 3   Computer science, computer engineering, or sof...  ...
# 4   Computer science, computer engineering, or sof...  ...
# ..                                                ...  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22  Information systems, information technology, o...  ...
# 23                                                NaN  ...
# 24  Computer science, computer engineering, or sof...  ...
#
#                                         WelcomeChange  \
# 0             Just as welcome now as I felt last year
# 1             Just as welcome now as I felt last year
# 2             Just as welcome now as I felt last year
# 3             Just as welcome now as I felt last year
# 4             Just as welcome now as I felt last year
# ..                                                ...
# 20  Not applicable - I did not use Stack Overflow ...
# 21            Just as welcome now as I felt last year
# 22            Just as welcome now as I felt last year
# 23            Just as welcome now as I felt last year
# 24            Just as welcome now as I felt last year
#
#                                          SONewContent   Age  Gender  Trans  \
# 0   Tech articles written by other developers;Indu...  14.0     Man     No
# 1   Tech articles written by other developers;Indu...  19.0     Man     No
# 2   Tech meetups or events in your area;Courses on...  28.0     Man     No
# 3   Tech articles written by other developers;Indu...  22.0     Man     No
# 4   Tech meetups or events in your area;Courses on...  30.0     Man     No
# ..                                                ...   ...     ...    ...
# 20                                                NaN   NaN     Man     No
# 21  Tech articles written by other developers;Indu...  47.0     Man     No
# 22  Tech articles written by other developers;Tech...  22.0     Man     No
# 23  Tech articles written by other developers;Indu...  23.0     Man     No
# 24                Tech meetups or events in your area  22.0     Man     No
#
#                   Sexuality                                 Ethnicity  \
# 0   Straight / Heterosexual                                       NaN
# 1   Straight / Heterosexual                                       NaN
# 2   Straight / Heterosexual                                       NaN
# 3   Straight / Heterosexual              White or of European descent
# 4   Straight / Heterosexual  White or of European descent;Multiracial
# ..                      ...                                       ...
# 20                      NaN                                       NaN
# 21  Straight / Heterosexual              White or of European descent
# 22  Straight / Heterosexual               Black or of African descent
# 23  Straight / Heterosexual                            Middle Eastern
# 24  Straight / Heterosexual              White or of European descent
#
#    Dependents           SurveyLength                  SurveyEase
# 0          No  Appropriate in length  Neither easy nor difficult
# 1          No  Appropriate in length  Neither easy nor difficult
# 2         Yes  Appropriate in length  Neither easy nor difficult
# 3          No  Appropriate in length                        Easy
# 4          No  Appropriate in length                        Easy
# ..        ...                    ...                         ...
# 20         No  Appropriate in length                        Easy
# 21        Yes  Appropriate in length                        Easy
# 22         No  Appropriate in length                        Easy
# 23         No  Appropriate in length                        Easy
# 24         No              Too short  Neither easy nor difficult
#
# [25 rows x 85 columns]

# %%
# 1st 5 rows

df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age  Gender  Trans  \
# 0  Tech articles written by other developers;Indu...  14.0     Man     No
# 1  Tech articles written by other developers;Indu...  19.0     Man     No
# 2  Tech meetups or events in your area;Courses on...  28.0     Man     No
# 3  Tech articles written by other developers;Indu...  22.0     Man     No
# 4  Tech meetups or events in your area;Courses on...  30.0     Man     No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
# 1st 5 rows

df.head(9)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
# 6                       Never
# 7     Less than once per year
# 8  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
# 6  The quality of OSS and closed source software ...
# 7  OSS is, on average, of HIGHER quality than pro...
# 8  The quality of OSS and closed source software ...
#
#                                           Employment                 Country  \
# 0             Not employed, and not looking for work          United Kingdom
# 1                 Not employed, but looking for work  Bosnia and Herzegovina
# 2                                 Employed full-time                Thailand
# 3                                 Employed full-time           United States
# 4                                 Employed full-time                 Ukraine
# 5                                 Employed full-time                  Canada
# 6  Independent contractor, freelancer, or self-em...                 Ukraine
# 7                 Not employed, but looking for work                   India
# 8                                 Employed full-time             New Zealand
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6              No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7             NaN         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8              No  Some college/university study without earning ...
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
# 5                          Mathematics or statistics  ...
# 6  Another engineering discipline (ex. civil, ele...  ...
# 7  Computer science, computer engineering, or sof...  ...
# 8  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
# 5  Just as welcome now as I felt last year
# 6    A lot more welcome now than last year
# 7    A lot more welcome now than last year
# 8  Just as welcome now as I felt last year
#
#                                         SONewContent   Age  Gender  Trans  \
# 0  Tech articles written by other developers;Indu...  14.0     Man     No
# 1  Tech articles written by other developers;Indu...  19.0     Man     No
# 2  Tech meetups or events in your area;Courses on...  28.0     Man     No
# 3  Tech articles written by other developers;Indu...  22.0     Man     No
# 4  Tech meetups or events in your area;Courses on...  30.0     Man     No
# 5  Tech articles written by other developers;Indu...  28.0     Man     No
# 6                                                NaN  42.0     Man     No
# 7  Tech articles written by other developers;Indu...  24.0     Man     No
# 8                                                NaN  23.0     Man     No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
# 5  Straight / Heterosexual                                East Asian
# 6  Straight / Heterosexual              White or of European descent
# 7  Straight / Heterosexual                                       NaN
# 8                 Bisexual              White or of European descent
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
# 5         No               Too long  Neither easy nor difficult
# 6        Yes  Appropriate in length  Neither easy nor difficult
# 7        NaN  Appropriate in length  Neither easy nor difficult
# 8         No  Appropriate in length  Neither easy nor difficult
#
# [9 rows x 85 columns]

# %%
# 1st 5 rows

df.tail()
# Out:
#     Respondent                      MainBranch Hobbyist  \
# 20          21     I code primarily as a hobby      Yes
# 21          22  I am a developer by profession      Yes
# 22          23  I am a developer by profession      Yes
# 23          24  I am a developer by profession      Yes
# 24          25  I am a developer by profession       No
#
#                    OpenSourcer  \
# 20  Once a month or more often
# 21     Less than once per year
# 22     Less than once per year
# 23                       Never
# 24                       Never
#
#                                            OpenSource          Employment  \
# 20  OSS is, on average, of HIGHER quality than pro...                 NaN
# 21  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 22  The quality of OSS and closed source software ...  Employed full-time
# 23  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 24  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 20         Canada     NaN                                                NaN
# 21  United States      No  Some college/university study without earning ...
# 22  United States      No         Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23         Israel      No                          Primary/elementary school
# 24   South Africa      No                                   Associate degree
#
#                                        UndergradMajor  ...  \
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22  Information systems, information technology, o...  ...
# 23                                                NaN  ...
# 24  Computer science, computer engineering, or sof...  ...
#
#                                         WelcomeChange  \
# 20  Not applicable - I did not use Stack Overflow ...
# 21            Just as welcome now as I felt last year
# 22            Just as welcome now as I felt last year
# 23            Just as welcome now as I felt last year
# 24            Just as welcome now as I felt last year
#
#                                          SONewContent   Age  Gender  Trans  \
# 20                                                NaN   NaN     Man     No
# 21  Tech articles written by other developers;Indu...  47.0     Man     No
# 22  Tech articles written by other developers;Tech...  22.0     Man     No
# 23  Tech articles written by other developers;Indu...  23.0     Man     No
# 24                Tech meetups or events in your area  22.0     Man     No
#
#                   Sexuality                     Ethnicity Dependents  \
# 20                      NaN                           NaN         No
# 21  Straight / Heterosexual  White or of European descent        Yes
# 22  Straight / Heterosexual   Black or of African descent         No
# 23  Straight / Heterosexual                Middle Eastern         No
# 24  Straight / Heterosexual  White or of European descent         No
#
#              SurveyLength                  SurveyEase
# 20  Appropriate in length                        Easy
# 21  Appropriate in length                        Easy
# 22  Appropriate in length                        Easy
# 23  Appropriate in length                        Easy
# 24              Too short  Neither easy nor difficult
#
# [5 rows x 85 columns]

# %%
import pandas as pd
person1 = {
    "Name": ["Alice", "Bob"],
    "Age": [25, 30]
}
df = pd.DataFrame(person1)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
import pandas as pd
person1 = {
    "Name": ["Ns loni", "loni"],
    "Age": [21, 20.9]
}
df = pd.DataFrame(person1)
print(df)
# Out:
#       Name   Age
# 0  Ns loni  21.0
# 1     loni  20.9

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
# pandas.core.series.Series

# %%
df.Age
# Out:
# 0    21.0
# 1    20.9
# Name: Age, dtype: float64

# %%
import pandas as pd
person1 = {
    "Name": ["Ns loni", "ns loni", 'ns loni', 'loni ns'],
    "Age": [21, 20.9,21,21],
    "email": ['sasawsas', 'sfdsfdfd','dfrwewef','sfsfwsef']
}
df = pd.DataFrame(person1)
print(df)
# Out:
#       Name   Age     email
# 0  Ns loni  21.0  sasawsas
# 1  ns loni  20.9  sfdsfdfd
# 2  ns loni  21.0  dfrwewef
# 3  loni ns  21.0  sfsfwsef

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'email'], dtype='object')

# %%
# Give '0th idx --> Row

df.iloc[0]
# Out:
# Name      Ns loni
# Age          21.0
# email    sasawsas
# Name: 0, dtype: object

# %%
df.iloc[[0,2]]
# Out:
#       Name   Age     email
# 0  Ns loni  21.0  sasawsas
# 2  ns loni  21.0  dfrwewef

# %%
df.iloc[[0,3]]
# Out:
#       Name   Age     email
# 0  Ns loni  21.0  sasawsas
# 3  loni ns  21.0  sfsfwsef

# %%
df.iloc[[0,1]]
# Out:
#       Name   Age     email
# 0  Ns loni  21.0  sasawsas
# 1  ns loni  20.9  sfdsfdfd

# %%
# Access Specific value

# Access the 2nd col values

df.iloc[[0,1], [2]]
# Out:
#       email
# 0  sasawsas
# 1  sfdsfdfd

# %%
df.iloc[0]
# Out:
# Name      Ns loni
# Age          21.0
# email    sasawsas
# Name: 0, dtype: object

# %%
df.loc[[0,1],['email']]
# Out:
#       email
# 0  sasawsas
# 1  sfdsfdfd

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'email'], dtype='object')

# %%
df['Name']
# Out:
# 0    Ns loni
# 1    ns loni
# 2    ns loni
# 3    loni ns
# Name: Name, dtype: object

# %%
# Inx---> Set / ReSet

# %%
print("Ns loni")
# Out:
# Ns loni

# %%
df.set_index('email')
# Out:
#              Name   Age
# email
# sasawsas  Ns loni  21.0
# sfdsfdfd  ns loni  20.9
# dfrwewef  ns loni  21.0
# sfsfwsef  loni ns  21.0

# %%
df.reset_index(inplace=True)
df
# Out:
#    index     Name   Age     email
# 0      0  Ns loni  21.0  sasawsas
# 1      1  ns loni  20.9  sfdsfdfd
# 2      2  ns loni  21.0  dfrwewef
# 3      3  loni ns  21.0  sfsfwsef
